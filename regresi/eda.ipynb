# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Load dataset
path = 'train.csv'
event_path = 'events_train.csv'

match_data = pd.read_csv(path)
events_data = pd.read_csv(event_path)

# %%
match_data.tail()
# Out:
#     match_id  match_date      kick_off  home_score  away_score  match_week  \
# 80   3773415  2021-02-21  14:00:00.000           1           1          24
# 81   3764440  2021-02-24  19:00:00.000           3           0           1
# 82   3773665  2021-03-06  21:00:00.000           0           2          26
# 83   3773369  2021-03-15  21:00:00.000           4           1          27
# 84   3773586  2021-04-29  19:00:00.000           1           2          33
#
#    home_team.home_team_name away_team.away_team_name      stadium.name  \
# 80                Barcelona                    Cádiz  Spotify Camp Nou
# 81                Barcelona                    Elche  Spotify Camp Nou
# 82                  Osasuna                Barcelona  Estadio El Sadar
# 83                Barcelona                   Huesca  Spotify Camp Nou
# 84                Barcelona                  Granada  Spotify Camp Nou
#
#                      referee.name    home_team.managers_name  \
# 80          Juan Martínez Munuera              Ronald Koeman
# 81  Isidro Díaz de Mera Escuderos              Ronald Koeman
# 82     Guillermo Cuadra Fernández  Jagoba Arrasate Elustondo
# 83            Adrián Cordero Vega              Ronald Koeman
# 84         Pablo González Fuertes              Ronald Koeman
#
#    home_team.managers_country home_team.managers_dob  \
# 80                Netherlands             1963-03-21
# 81                Netherlands             1963-03-21
# 82                      Spain             1978-04-22
# 83                Netherlands             1963-03-21
# 84                Netherlands             1963-03-21
#
#      away_team.managers_name away_team.managers_country  \
# 80       Álvaro Cervera Díaz                      Spain
# 81  Francisco Escriba Segura                      Spain
# 82             Ronald Koeman                Netherlands
# 83     Juan José Rojo Martín                      Spain
# 84      Diego Martínez Penas                      Spain
#
#    away_team.managers_dob  Poss Result
# 80             1965-09-20  19.0   Draw
# 81             1965-05-03  35.0    Win
# 82             1963-03-21  63.0   Lose
# 83             1968-03-23  31.0    Win
# 84             1980-12-16  19.0   Lose

# %%
events_data.tail()
# Out:
#                                           id  index  period     timestamp  \
# 328670  5491f041-8e91-4d81-a698-148684af52ef   4032       2  00:47:56.685
# 328671  533193c4-fd30-496c-b8fb-865664e11082   4033       2  00:47:58.155
# 328672  a6c939dd-6a8e-4683-8c96-96850322752f   4034       2  00:47:58.155
# 328673  37a300ed-f542-485c-a3c8-7f1c7e3969ff   4035       2  00:48:02.016
# 328674  659ab26c-7ac3-41d9-a69f-7f25901c8eab   4036       2  00:48:02.016
#
#         possession  duration      type.name possession_team.name  \
# 328670         224   1.46939           Pass              Osasuna
# 328671         224       NaN  Ball Receipt*              Osasuna
# 328672         224   0.00000      Clearance              Osasuna
# 328673         224   0.00000       Half End              Osasuna
# 328674         224   0.00000       Half End              Osasuna
#
#        play_pattern.name  team.name  ... goalkeeper.shot_saved_to_post  \
# 328670      Regular Play  Barcelona  ...                           NaN
# 328671      Regular Play  Barcelona  ...                           NaN
# 328672      Regular Play    Osasuna  ...                           NaN
# 328673      Regular Play    Osasuna  ...                           NaN
# 328674      Regular Play  Barcelona  ...                           NaN
#
#        goalkeeper.lost_out foul_committed.penalty foul_won.penalty  \
# 328670                 NaN                    NaN              NaN
# 328671                 NaN                    NaN              NaN
# 328672                 NaN                    NaN              NaN
# 328673                 NaN                    NaN              NaN
# 328674                 NaN                    NaN              NaN
#
#         goalkeeper.success_in_play block.save_block shot.follows_dribble  \
# 328670                         NaN              NaN                  NaN
# 328671                         NaN              NaN                  NaN
# 328672                         NaN              NaN                  NaN
# 328673                         NaN              NaN                  NaN
# 328674                         NaN              NaN                  NaN
#
#        goalkeeper.success_out player_off.permanent goalkeeper.lost_in_play
# 328670                    NaN                  NaN                     NaN
# 328671                    NaN                  NaN                     NaN
# 328672                    NaN                  NaN                     NaN
# 328673                    NaN                  NaN                     NaN
# 328674                    NaN                  NaN                     NaN
#
# [5 rows x 101 columns]
